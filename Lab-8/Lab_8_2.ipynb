# %%
import time
import warnings

import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

np.random.seed(0)

# %%
n_samples = 1500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,noise=.05)


noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
X,y=noisy_moons
#normalize dataset for easier parameter selection
X = StandardScaler().fit_transform(X)

# %%
noisy_circles
# Out:
# (array([[-0.67799938, -0.69875698],
#         [ 0.93143746,  0.19139133],
#         [ 0.54829131, -0.00601715],
#         ...,
#         [-0.34518816, -0.35804797],
#         [ 0.01719727, -0.94513802],
#         [ 0.91377877, -0.59884164]]), array([0, 0, 1, ..., 1, 0, 0]))

# %%
X,y=noisy_circles

# %%
X
# Out:
# array([[-0.67799938, -0.69875698],
#        [ 0.93143746,  0.19139133],
#        [ 0.54829131, -0.00601715],
#        ...,
#        [-0.34518816, -0.35804797],
#        [ 0.01719727, -0.94513802],
#        [ 0.91377877, -0.59884164]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.4, random_state=42)

# %%
colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_train) + 1))))
plt.scatter(X_train[:, 0], X_train[:, 1], s=10, color=colors[y_train])
plt.xlim(-2.5, 2.5)
plt.ylim(-2.5, 2.5)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
clf = make_pipeline(StandardScaler(), SVC(kernel="linear", C=0.025))
clf.fit(X_train, y_train)
y_pred=clf.predict(X_test)

# %%
clf1 = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf1.fit(X_train, y_train)
y_pred1=clf1.predict(X_test)

# %%
colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_test) + 1))))
plt.scatter(X_test[:, 0], X_test[:, 1], s=10, color=colors[y_test])
plt.xlim(-2.5, 2.5)
plt.ylim(-2.5, 2.5)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_pred) + 1))))
plt.scatter(X_test[:, 0], X_test[:, 1], s=10, color=colors[y_pred])
plt.xlim(-2.5, 2.5)
plt.ylim(-2.5, 2.5)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_pred1) + 1))))
plt.scatter(X_test[:, 0], X_test[:, 1], s=10, color=colors[y_pred1])
plt.xlim(-2.5, 2.5)
plt.ylim(-2.5, 2.5)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
#X,y=noisy_circles
X,y=noisy_moons
X = StandardScaler().fit_transform(X)

# %%
X.shape
# Out:
# (1500, 2)

# %%
X_new=np.zeros((X.shape[0],X.shape[1]+10))
X_new.shape
# Out:
# (1500, 12)

# %%
import numpy as np
for i in range(X.shape[0]):
  '''
  X_new[i][0:2]=X[i]
  '''

    
  '''
  X_new[i][0:2]=X[i]
  X_new[i][3]=X[i][0]*X[i][1]
  X_new[i][4]=1
  '''
  
  '''
  X_new[i][0:2]=X[i]

  X_new[i][2]=2*(X[i][0])*(X[i][1])
  X_new[i][3]=(X[i][1])**2
  X_new[i][4]=(X[i][0])**2
  X_new[i][5]=1
  '''
  
  
  
  X_new[i][0:2]=3*X[i]
  X_new[i][2]=(X[i][0])**3
  X_new[i][3]=(X[i][1])**3
  X_new[i][4]=(3*(X[i][0]**2)*X[i][1])
  X_new[i][5]=(3*(X[i][1]**2)*X[i][0])
  X_new[i][6]=(3*(X[i][0]**2))
  X_new[i][7]=(3*(X[i][1]**2))
  X_new[i][8]=(6*(X[i][0]*X[i][1]))
  X_new[i][9]=1

# %%
from sklearn.model_selection import train_test_split
X_new_train, X_new_test, y_new_train, y_new_test = train_test_split(X_new, y, test_size=.4, random_state=42)

# %%
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
clf = make_pipeline(StandardScaler(), SVC(kernel="linear", C=0.025))
clf.fit(X_new_train, y_new_train)
y_new_pred=clf.predict(X_new_test)

# %%
colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_new_pred) + 1))))
plt.scatter(X_new_test[:, 0], X_new_test[:, 1], s=10, color=colors[y_new_pred])
#plt.xlim(-2.5, 2.5)
#plt.ylim(-2.5, 2.5)
#plt.xticks(())
#plt.yticks(())
plt.show()
